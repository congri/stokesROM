# %%
"""This should be the main module for the python Stokes/Darcy problem.
The code architecture still needs to be specified."""

from stokesdata import StokesData
from reducedordermodel import ReducedOrderModel
from modelparameters import ModelParameters
import numpy as np
import dolfin as df
import multiprocessing as mp
import scipy.optimize as opt
import time
import VI.variationalinference as VI
import matplotlib.pyplot as plt
import romtoolbox as rt

df.set_log_level(30)

modelParams = ModelParameters()
trainingData = StokesData()
# trainingData.genData()
trainingData.loadData(('mesh', 'solution'))
trainingData.interpolate('p', modelParams)
trainingData.shiftData()
trainingData.computeDesignMatrix(modelParams)
trainingData.normalizeDesignMatrix(modelParams)
trainingData.shapeToLocalDesignMatrix()

# theta_c can only be initialized when design matrices exist, i.e. number of features is known
modelParams.theta_c = .0 * np.ones(trainingData.designMatrix[0].shape[1])
modelParams.initHyperparams()

# Step width for ADAM optimization in VI
sw = 1e-1 * np.ones(2 * modelParams.coarseMesh.num_cells())
sw_decay = .95      # step width decay per epoch
sw_min = 8e-3 * np.ones(2 * modelParams.coarseMesh.num_cells())

# Bring variational distribution params in form for unconstrained optimization
mu_lambda_c = np.zeros(modelParams.coarseMesh.num_cells())
sigma_lambda_c = np.ones(modelParams.coarseMesh.num_cells())
varDistParamsVec = trainingData.samples.size * [np.concatenate((mu_lambda_c, -2 * np.log(sigma_lambda_c)))]


# training phase starts here
converged = False
train_iter = 0
epoch = 0   # one epoch == every data point has been seen once
thetaArray = np.expand_dims(modelParams.theta_c, axis=1)
sigmaArray = np.expand_dims(modelParams.Sigma_c, axis=1)
gammaArray = np.expand_dims(modelParams.gamma, axis=1)
elboList = []


rom = ReducedOrderModel(modelParams, trainingData)

# paramsVec contains [mu, -2*log(sigma)] for every data point
modelParams.paramsVec = trainingData.samples.size * [np.zeros(2*modelParams.coarseMesh.num_cells())]
x_0 = np.zeros(modelParams.coarseMesh.num_cells())      # start point for pre-VI maximization
x_0 = trainingData.samples.size * [x_0]
sq_dist = trainingData.samples.size * [None]

while not converged:

    # print('Performing pre-VI maximization...')
    #
    # def neg_log_q(X, Phi, p):
    #     lg_q, d_lg_q = rom.log_q_n(X, Phi, p)
    #     return -lg_q, -d_lg_q
    #
    #
    # def minimize_neg_log_q(arg):
    #     neg_lg_q, x_init, Phi, p_interp = arg
    #     res = opt.minimize(neg_lg_q, x_init, method='BFGS', jac=True, args=(Phi, p_interp))
    #     return res.x
    #
    # args = [(neg_log_q, modelParams.paramsVec[n][:modelParams.coarseMesh.num_cells()], trainingData.designMatrix[n],
    #          trainingData.p_interp[n].vector().get_local()) for n in trainingData.samples]
    #
    # max_x = []
    # maxmode = 'parallel'
    # if maxmode == 'serial':
    #     for arg_n in args:
    #         x = minimize_neg_log_q(arg_n)
    #         max_x.append(x)
    # elif maxmode == 'parallel':
    #     parpool = mp.Pool(trainingData.samples.size)
    #     max_x = parpool.map(minimize_neg_log_q, args)
    #     parpool.close()
    #
    # for n in trainingData.samples:
    #     modelParams.paramsVec[n][0:modelParams.coarseMesh.num_cells()] = max_x[n]
    #
    # print('...pre-VI maximization done.')

    # VI starts here
    vimode = 'parallel'
    t_s = time.time()


    def varinf(arg):
        paramsVec_n, Phi_n, pp = arg

        def log_emp_dist(x):
            lg_q_emp, d_lg_q_emp = rom.log_q_n(x, Phi_n, pp)
            return lg_q_emp, d_lg_q_emp

        paramsVec_n = VI.variationalInference(paramsVec_n, log_emp_dist)
        return paramsVec_n


    if vimode == 'serial':
        print('Performing serial variational inference...')
        for n in trainingData.samples:
            modelParams.paramsVec[n] = varinf((modelParams.paramsVec[n].copy(), trainingData.designMatrix[n],
                                       trainingData.p_interp[n].vector().get_local()))

    elif vimode == 'parallel':
        print('Performing variational inference in parallel...')
        args = [(modelParams.paramsVec[n].copy(), trainingData.designMatrix[n].copy(),
                 trainingData.p_interp[n].vector().get_local().copy()) for n in trainingData.samples]

        parpool = mp.Pool(trainingData.samples.size)
        modelParams.paramsVec = parpool.map(varinf, args)
        parpool.close()

    print('...variational inference done.')
    t_e = time.time()

    for n in range(trainingData.samples.size):
        sq_dist[n] = rom.expected_sq_dist(modelParams.paramsVec[n], trainingData.p_interp[n].vector().get_local())

    t_s = time.time()
    elbo, cell_score = rom.M_step(sq_dist)
    elboList.append(elbo)
    t_e = time.time()
    print('M_step time = ', t_e - t_s)
    print('theta_c = ', modelParams.theta_c)
    print('gamma = ', modelParams.gamma[:2])
    print('elbo =', elbo)
    print('cell score = ', cell_score)

    x_c_mode = trainingData.designMatrix[0].dot(modelParams.theta_c)
    effdiff, _ = rt.diffusivityTransform(x_c_mode, 'log', 'backward', return_grad=True)
    print('lambda_c0 = ', effdiff)

    theta_temp = np.expand_dims(modelParams.theta_c, axis=1)
    thetaArray = np.append(thetaArray, theta_temp, axis=1)
    sigma_temp = np.expand_dims(modelParams.Sigma_c, axis=1)
    sigmaArray = np.append(sigmaArray, sigma_temp, axis=1)
    gamma_temp = np.expand_dims(modelParams.gamma, axis=1)
    gammaArray = np.append(gammaArray, gamma_temp, axis=1)

    # plot current parameters
    t_s = time.time()
    if not plt.fignum_exists(1):
        figParams = plt.figure(1)
#         figParams.show()
        for i in range(6):
            figParams.add_subplot(3, 2, i + 1)
#         mngr = plt.get_current_fig_manager()
#         mngr.window.setGeometry(0, 0, 960, 1200)  # half Dell display
    modelParams.plot(figParams, thetaArray, sigmaArray, gammaArray)
    t_e = time.time()
    print('plot params time = ', t_e - t_s)

    # plot current state
    t_s = time.time()
    if not plt.fignum_exists(2):
        figState = plt.figure(2)
#         figState.show()
        for i in range(6):
            if (i + 1) % 3 == 0:
                figState.add_subplot(2, 3, i + 1, projection='3d')
            else:
                figState.add_subplot(2, 3, i + 1)
#         mngr = plt.get_current_fig_manager()
#         mngr.window.setGeometry(50, 50, 1820, 1100)  # full Dell display
    rom.plot_current_state(figState)
    t_e = time.time()
    print('plot state time = ', t_e - t_s)

    t_s = time.time()
    # plot elbo
    if not plt.fignum_exists(3):
        figElbo = plt.figure(3)
#         figElbo.show()
        ax_elbo = figElbo.add_subplot(1, 1, 1)
#         mngr = plt.get_current_fig_manager()
#         mngr.window.setGeometry(50, 50, 1820, 1100)  # full Dell display
        ax_elbo.grid(True)
        ax_elbo.set_xlabel('iteration')
        ax_elbo.set_ylabel(r'elbo')
    ax_elbo.plot(np.arange(0, train_iter + 1), elboList, 'kx')
    ax_elbo.set_xlim((0.0, train_iter + 1))
    figElbo.canvas.draw()
    figElbo.canvas.flush_events()
    # figElbo.savefig('elbo.png')
    time.sleep(.01)
    t_e = time.time()
    print('plot elbo time = ', t_e - t_s)

    if train_iter >= modelParams.max_iterations:
        converged = True
    else:
        train_iter += 1
# Out:
# Interpolating data onto regular grid...
# ...data interpolated.
# Shifting data such that pressure is  0.0  at  [ 0.  0.]  ...
# ...data shifted.
# Rescaling design matrix...
# ...design matrix rescaled.
# Reshaping design matrix for separate feature coefficients theta_c  for each macro-cell in a microstructure...
# ...design matrices reshaped to local.
# Performing variational inference in parallel...
# Converged because max computation time exceeded
# Converged because max computation time exceeded
# Converged because max computation time exceeded
# Converged because max computation time exceeded
# Converged because max computation time exceeded
# Converged because max computation time exceeded
# Converged because max computation time exceeded
# Converged because max computation time exceeded
# ...variational inference done.
# mean_p_cf_std =  12526.0375469
# M_step time =  0.0037593841552734375
# theta_c =  [-6.67635514  3.25782417 -4.96383026 -1.2789996  -6.70607254 -0.19323769
#  -7.43849962 -0.02449299 -6.80698751 -2.94080848 -0.82576206 -0.09542012
#  -6.48370637  0.85835422 -0.97958499 -0.78045225]
# gamma =  [ 0.00091848  0.00062777]
# elbo = -1963619.84493
# cell score =  [-19.41226407 -47.17362713 -43.92788056 -41.82926215 -29.19795897
#  -24.99450917 -33.42550711 -11.72244873]
# lambda_c0 =  [  9.28737404e-03   3.09429224e-03   1.08487402e-03   5.83893677e-04
#    8.80503062e-05   4.08798567e-01   2.14067615e-03   2.23048297e-01]
# plot params time =  0.8412661552429199
# plot state time =  13.183081865310669
# plot elbo time =  0.060595035552978516
# Performing variational inference in parallel...
# /home/constantin/cluster/python/projects/stokesEquation/romtoolbox.py:29: RuntimeWarning: overflow encountered in exp
#   diffusivity = np.exp(x)
# /home/constantin/cluster/python/projects/stokesEquation/romtoolbox.py:29: RuntimeWarning: overflow encountered in exp
#   diffusivity = np.exp(x)
# /home/constantin/cluster/python/projects/stokesEquation/romtoolbox.py:29: RuntimeWarning: overflow encountered in exp
#   diffusivity = np.exp(x)
# /home/constantin/cluster/python/projects/stokesEquation/romtoolbox.py:29: RuntimeWarning: overflow encountered in exp
#   diffusivity = np.exp(x)
# Converged because max computation time exceeded
# Converged because max computation time exceeded
# Converged because max computation time exceeded
# Converged because max computation time exceeded
# Converged because max computation time exceeded
# Converged because max computation time exceeded
# Converged because max computation time exceeded
# Converged because max computation time exceeded
# ...variational inference done.
# mean_p_cf_std =  10880.9037536
# M_step time =  0.003304004669189453
# theta_c =  [ -4.76805153   1.34099024  -5.95919701   0.78100283  -7.23205439
#    0.17264742 -10.15345964   3.79459913  -5.8407195   -2.65862683
#   -1.01397596   0.86092151  -8.1312507    2.25999821  -0.11813931
#   -0.06755616]
# gamma =  [ 0.01887777  0.01639105]
# elbo = -1946848.43516
# cell score =  [-17.07955368 -26.61968367 -24.35939074 -22.93759792 -13.18792632
#   -9.88385086 -20.11854613 -10.74741225]
# lambda_c0 =  [  1.93330678e-02   4.24541305e-03   8.05018466e-04   1.20515159e-04
#    2.95006779e-04   6.74693252e-01   7.14621901e-04   8.49405706e-01]
# plot params time =  0.30633068084716797
# plot state time =  13.618530035018921
# plot elbo time =  0.04666709899902344
# Performing variational inference in parallel...
# Converged because max computation time exceeded
# Converged because max computation time exceeded
# Converged because max computation time exceeded
# Converged because max computation time exceeded
# Converged because max computation time exceeded
# Converged because max computation time exceeded
# Converged because max computation time exceeded
# Converged because max computation time exceeded
# ...variational inference done.
# mean_p_cf_std =  8530.1445097
# M_step time =  0.003622293472290039
# theta_c =  [ -7.11189064   2.86500921  -7.41695535   2.89380414  -9.2056197
#    3.82991221 -10.68212503   4.84760428  -5.5374977   -2.93217     -0.79775804
#    0.52340139  -8.44968352   4.20818212  -0.33902124  -0.09004226]
# gamma =  [ 0.02029093  0.03244799]
# elbo = -1918632.26526
# cell score =  [-20.76666056 -22.92993807 -23.05612083 -18.78047338 -15.01473179
#   -9.25366217 -18.19693859 -13.61701766]
# lambda_c0 =  [  4.72231674e-03   3.79371440e-03   1.08853956e-03   9.71843697e-05
#    3.15712401e-04   6.56695436e-01   1.11696011e-03   6.70920352e-01]
# plot params time =  0.28306007385253906
# plot state time =  13.344141006469727
# plot elbo time =  0.033799171447753906
# Performing variational inference in parallel...
# Process ForkPoolWorker-39:
# Process ForkPoolWorker-38:
# Process ForkPoolWorker-40:
# Process ForkPoolWorker-35:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-34:
# Traceback (most recent call last):
# Process ForkPoolWorker-36:
# Process ForkPoolWorker-37:
# Traceback (most recent call last):
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/_collections_abc.py", line 597, in get
#     return self[key]
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/os.py", line 725, in __getitem__
#     raise KeyError(key) from None
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# KeyError: 'FFC_FORCE_REPRESENTATION'
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
# Traceback (most recent call last):
# Traceback (most recent call last):
# Process ForkPoolWorker-41:
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#
# During handling of the above exception, another exception occurred:
#
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "<ipython-input-1-5388f44dd57a>", line 106, in varinf
#     paramsVec_n = VI.variationalInference(paramsVec_n, log_emp_dist)
# Traceback (most recent call last):
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-1-5388f44dd57a>", line 106, in varinf
#     paramsVec_n = VI.variationalInference(paramsVec_n, log_emp_dist)
# Traceback (most recent call last):
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
# Traceback (most recent call last):
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/constantin/cluster/python/projects/stokesEquation/VI/variationalinference.py", line 64, in variationalInference
#     paramsVec = sopt.amsGradOpt(paramsVec)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/home/constantin/cluster/python/projects/stokesEquation/VI/variationalinference.py", line 64, in variationalInference
#     paramsVec = sopt.amsGradOpt(paramsVec)
#   File "<ipython-input-1-5388f44dd57a>", line 106, in varinf
#     paramsVec_n = VI.variationalInference(paramsVec_n, log_emp_dist)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/home/constantin/cluster/python/projects/stokesEquation/VI/stochopt.py", line 65, in amsGradOpt
#     grad = self.gradfun(x)
#   File "/home/constantin/cluster/python/projects/stokesEquation/VI/stochopt.py", line 65, in amsGradOpt
#     grad = self.gradfun(x)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/constantin/cluster/python/projects/stokesEquation/VI/variationalinference.py", line 64, in variationalInference
#     paramsVec = sopt.amsGradOpt(paramsVec)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/home/constantin/cluster/python/projects/stokesEquation/VI/variationalinference.py", line 59, in gradfun
#     grad, _ = elboGrad(x, log_emp_dist, nSamples, varDist)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/constantin/cluster/python/projects/stokesEquation/VI/stochopt.py", line 65, in amsGradOpt
#     grad = self.gradfun(x)
#   File "/home/constantin/cluster/python/projects/stokesEquation/VI/variationalinference.py", line 59, in gradfun
#     grad, _ = elboGrad(x, log_emp_dist, nSamples, varDist)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/home/constantin/cluster/python/projects/stokesEquation/VI/variationalinference.py", line 26, in elboGrad
#     _, d_log_empirical = log_emp_dist(variationalSample)
#   File "/home/constantin/cluster/python/projects/stokesEquation/VI/variationalinference.py", line 59, in gradfun
#     grad, _ = elboGrad(x, log_emp_dist, nSamples, varDist)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/constantin/cluster/python/projects/stokesEquation/VI/variationalinference.py", line 30, in elboGrad
#     d_mu_mean = (1.0/(i + 1.0))*(i * d_mu_mean + d_log_empirical)
#   File "<ipython-input-1-5388f44dd57a>", line 103, in log_emp_dist
#     lg_q_emp, d_lg_q_emp = rom.log_q_n(x, Phi_n, pp)
#   File "/home/constantin/cluster/python/projects/stokesEquation/VI/variationalinference.py", line 26, in elboGrad
#     _, d_log_empirical = log_emp_dist(variationalSample)
# KeyboardInterrupt
#   File "<ipython-input-1-5388f44dd57a>", line 106, in varinf
#     paramsVec_n = VI.variationalInference(paramsVec_n, log_emp_dist)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/constantin/cluster/python/projects/stokesEquation/reducedordermodel.py", line 60, in log_q_n
#     u_c_n = self.coarseSolver.solvePDE(diffusivityFunction)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/constantin/cluster/python/projects/stokesEquation/VI/variationalinference.py", line 64, in variationalInference
#     paramsVec = sopt.amsGradOpt(paramsVec)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/constantin/cluster/python/projects/stokesEquation/dolfinpoisson.py", line 39, in solvePDE
#     df.solve(a == L, u, self.bcPressure)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "<ipython-input-1-5388f44dd57a>", line 103, in log_emp_dist
#     lg_q_emp, d_lg_q_emp = rom.log_q_n(x, Phi_n, pp)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/constantin/cluster/python/projects/stokesEquation/VI/stochopt.py", line 65, in amsGradOpt
#     grad = self.gradfun(x)
#   File "<ipython-input-1-5388f44dd57a>", line 106, in varinf
#     paramsVec_n = VI.variationalInference(paramsVec_n, log_emp_dist)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "<ipython-input-1-5388f44dd57a>", line 106, in varinf
#     paramsVec_n = VI.variationalInference(paramsVec_n, log_emp_dist)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/site-packages/dolfin/fem/solving.py", line 300, in solve
#     _solve_varproblem(*args, **kwargs)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/pool.py", line 119, in worker
#     result = (True, func(*args, **kwds))
#   File "/home/constantin/cluster/python/projects/stokesEquation/reducedordermodel.py", line 64, in log_q_n
#     adjoints = self.coarseSolver.getAdjoints(diffusivityFunction, d_lg_p_cf_n_d_u_c)
#   File "/home/constantin/cluster/python/projects/stokesEquation/VI/variationalinference.py", line 59, in gradfun
#     grad, _ = elboGrad(x, log_emp_dist, nSamples, varDist)
#   File "/home/constantin/cluster/python/projects/stokesEquation/VI/variationalinference.py", line 64, in variationalInference
#     paramsVec = sopt.amsGradOpt(paramsVec)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/site-packages/dolfin/fem/solving.py", line 325, in _solve_varproblem
#     form_compiler_parameters=form_compiler_parameters)
#   File "<ipython-input-1-5388f44dd57a>", line 106, in varinf
#     paramsVec_n = VI.variationalInference(paramsVec_n, log_emp_dist)
#   File "/home/constantin/cluster/python/projects/stokesEquation/VI/variationalinference.py", line 64, in variationalInference
#     paramsVec = sopt.amsGradOpt(paramsVec)
#   File "/home/constantin/cluster/python/projects/stokesEquation/VI/variationalinference.py", line 26, in elboGrad
#     _, d_log_empirical = log_emp_dist(variationalSample)
#   File "/home/constantin/cluster/python/projects/stokesEquation/dolfinpoisson.py", line 55, in getAdjoints
#     adjoints = np.linalg.solve(K.T, dJ)
#   File "/home/constantin/cluster/python/projects/stokesEquation/VI/stochopt.py", line 65, in amsGradOpt
#     grad = self.gradfun(x)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/pool.py", line 44, in mapstar
#     return list(map(*args))
#   File "/home/constantin/cluster/python/projects/stokesEquation/VI/stochopt.py", line 65, in amsGradOpt
#     grad = self.gradfun(x)
#   File "/home/constantin/cluster/python/projects/stokesEquation/VI/variationalinference.py", line 64, in variationalInference
#     paramsVec = sopt.amsGradOpt(paramsVec)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/site-packages/dolfin/fem/solving.py", line 81, in __init__
#     L = Form(L, form_compiler_parameters=form_compiler_parameters)
#   File "<ipython-input-1-5388f44dd57a>", line 103, in log_emp_dist
#     lg_q_emp, d_lg_q_emp = rom.log_q_n(x, Phi_n, pp)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/site-packages/numpy/linalg/linalg.py", line 375, in solve
#     r = gufunc(a, b, signature=signature, extobj=extobj)
#   File "/home/constantin/cluster/python/projects/stokesEquation/VI/variationalinference.py", line 59, in gradfun
#     grad, _ = elboGrad(x, log_emp_dist, nSamples, varDist)
#   File "<ipython-input-1-5388f44dd57a>", line 106, in varinf
#     paramsVec_n = VI.variationalInference(paramsVec_n, log_emp_dist)
#   File "/home/constantin/cluster/python/projects/stokesEquation/VI/variationalinference.py", line 59, in gradfun
#     grad, _ = elboGrad(x, log_emp_dist, nSamples, varDist)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/site-packages/dolfin/fem/form.py", line 92, in __init__
#     mpi_comm=mesh.mpi_comm())
#   File "/home/constantin/cluster/python/projects/stokesEquation/VI/variationalinference.py", line 26, in elboGrad
#     _, d_log_empirical = log_emp_dist(variationalSample)
# KeyboardInterrupt
#   File "/home/constantin/cluster/python/projects/stokesEquation/VI/stochopt.py", line 65, in amsGradOpt
#     grad = self.gradfun(x)
#   File "/home/constantin/cluster/python/projects/stokesEquation/VI/variationalinference.py", line 64, in variationalInference
#     paramsVec = sopt.amsGradOpt(paramsVec)
#   File "<ipython-input-1-5388f44dd57a>", line 103, in log_emp_dist
#     lg_q_emp, d_lg_q_emp = rom.log_q_n(x, Phi_n, pp)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/site-packages/dolfin/compilemodules/jit.py", line 70, in mpi_jit
#     return local_jit(*args, **kwargs)
#   File "/home/constantin/cluster/python/projects/stokesEquation/reducedordermodel.py", line 60, in log_q_n
#     u_c_n = self.coarseSolver.solvePDE(diffusivityFunction)
#   File "/home/constantin/cluster/python/projects/stokesEquation/reducedordermodel.py", line 60, in log_q_n
#     u_c_n = self.coarseSolver.solvePDE(diffusivityFunction)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/site-packages/dolfin/compilemodules/jit.py", line 142, in jit
#     result = ffc.jit(ufl_object, parameters=p)
#   File "/home/constantin/cluster/python/projects/stokesEquation/VI/variationalinference.py", line 59, in gradfun
#     grad, _ = elboGrad(x, log_emp_dist, nSamples, varDist)
#   File "/home/constantin/cluster/python/projects/stokesEquation/dolfinpoisson.py", line 39, in solvePDE
#     df.solve(a == L, u, self.bcPressure)
#   File "/home/constantin/cluster/python/projects/stokesEquation/VI/variationalinference.py", line 26, in elboGrad
#     _, d_log_empirical = log_emp_dist(variationalSample)
#   File "/home/constantin/cluster/python/projects/stokesEquation/VI/stochopt.py", line 65, in amsGradOpt
#     grad = self.gradfun(x)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/site-packages/dolfin/fem/solving.py", line 300, in solve
#     _solve_varproblem(*args, **kwargs)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/site-packages/ffc/jitcompiler.py", line 215, in jit
#     kind, module_name = compute_jit_prefix(ufl_object, parameters)
#   File "/home/constantin/cluster/python/projects/stokesEquation/VI/variationalinference.py", line 26, in elboGrad
#     _, d_log_empirical = log_emp_dist(variationalSample)
#   File "/home/constantin/cluster/python/projects/stokesEquation/dolfinpoisson.py", line 39, in solvePDE
#     df.solve(a == L, u, self.bcPressure)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/site-packages/dolfin/fem/solving.py", line 325, in _solve_varproblem
#     form_compiler_parameters=form_compiler_parameters)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/site-packages/dolfin/fem/solving.py", line 300, in solve
#     _solve_varproblem(*args, **kwargs)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/site-packages/dolfin/fem/solving.py", line 81, in __init__
#     L = Form(L, form_compiler_parameters=form_compiler_parameters)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/site-packages/ffc/jitcompiler.py", line 144, in compute_jit_prefix
#     object_signature = ufl_object.signature()
#   File "<ipython-input-1-5388f44dd57a>", line 103, in log_emp_dist
#     lg_q_emp, d_lg_q_emp = rom.log_q_n(x, Phi_n, pp)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/site-packages/dolfin/fem/solving.py", line 325, in _solve_varproblem
#     form_compiler_parameters=form_compiler_parameters)
#   File "/home/constantin/cluster/python/projects/stokesEquation/VI/variationalinference.py", line 59, in gradfun
#     grad, _ = elboGrad(x, log_emp_dist, nSamples, varDist)
#   File "/home/constantin/cluster/python/projects/stokesEquation/reducedordermodel.py", line 63, in log_q_n
#     lg_p_cf_n, d_lg_p_cf_n_d_u_c = self.log_p_cf(u_c_n, u_f_n, self.modelParams.Sinv_vec)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/site-packages/dolfin/fem/form.py", line 92, in __init__
#     mpi_comm=mesh.mpi_comm())
#   File "/home/constantin/cluster/python/projects/stokesEquation/VI/variationalinference.py", line 26, in elboGrad
#     _, d_log_empirical = log_emp_dist(variationalSample)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/site-packages/ufl/form.py", line 234, in signature
#     self._compute_signature()
#   File "/home/constantin/cluster/python/projects/stokesEquation/reducedordermodel.py", line 25, in log_p_cf
#     diff_n = np.array(self.modelParams.W.dot(u_c) - u_f_n)
#   File "<ipython-input-1-5388f44dd57a>", line 103, in log_emp_dist
#     lg_q_emp, d_lg_q_emp = rom.log_q_n(x, Phi_n, pp)
# KeyboardInterrupt
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/site-packages/ufl/form.py", line 475, in _compute_signature
#     self._compute_renumbering())
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/site-packages/dolfin/compilemodules/jit.py", line 70, in mpi_jit
#     return local_jit(*args, **kwargs)
#   File "<ipython-input-1-5388f44dd57a>", line 103, in log_emp_dist
#     lg_q_emp, d_lg_q_emp = rom.log_q_n(x, Phi_n, pp)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/site-packages/dolfin/fem/solving.py", line 82, in __init__
#     a = Form(a, form_compiler_parameters=form_compiler_parameters)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/site-packages/ufl/algorithms/signature.py", line 173, in compute_form_signature
#     return hashlib.sha512(data).hexdigest()
#   File "/home/constantin/cluster/python/projects/stokesEquation/reducedordermodel.py", line 60, in log_q_n
#     u_c_n = self.coarseSolver.solvePDE(diffusivityFunction)
# KeyboardInterrupt
#   File "/home/constantin/cluster/python/projects/stokesEquation/reducedordermodel.py", line 63, in log_q_n
#     lg_p_cf_n, d_lg_p_cf_n_d_u_c = self.log_p_cf(u_c_n, u_f_n, self.modelParams.Sinv_vec)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/site-packages/dolfin/fem/form.py", line 72, in __init__
#     sd = form.subdomain_data()
#   File "/home/constantin/cluster/python/projects/stokesEquation/reducedordermodel.py", line 30, in log_p_cf
#     d_log_p_d_u_c = - np.dot(Sinv_vec*diff_n, self.modelParams.W)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/site-packages/dolfin/compilemodules/jit.py", line 137, in jit
#     p.update(parameters["form_compiler"])
#   File "/home/constantin/cluster/python/projects/stokesEquation/dolfinpoisson.py", line 39, in solvePDE
#     df.solve(a == L, u, self.bcPressure)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/site-packages/dolfin/cpp/common.py", line 1800, in update
#     self.__setitem__(key, other_value)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/site-packages/dolfin/fem/solving.py", line 300, in solve
#     _solve_varproblem(*args, **kwargs)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/site-packages/dolfin/cpp/common.py", line 1779, in __setitem__
#     from six import string_types
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/site-packages/dolfin/fem/solving.py", line 325, in _solve_varproblem
#     form_compiler_parameters=form_compiler_parameters)
# KeyboardInterrupt
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/site-packages/dolfin/fem/solving.py", line 82, in __init__
#     a = Form(a, form_compiler_parameters=form_compiler_parameters)
# KeyboardInterrupt
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/site-packages/dolfin/fem/form.py", line 92, in __init__
#     mpi_comm=mesh.mpi_comm())
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/site-packages/ufl/form.py", line 202, in subdomain_data
#     self._analyze_subdomain_data()
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/site-packages/dolfin/compilemodules/jit.py", line 70, in mpi_jit
#     return local_jit(*args, **kwargs)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/site-packages/dolfin/compilemodules/jit.py", line 142, in jit
#     result = ffc.jit(ufl_object, parameters=p)
# KeyboardInterrupt
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/site-packages/ffc/jitcompiler.py", line 207, in jit
#     parameters = validate_jit_parameters(parameters)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/site-packages/ffc/parameters.py", line 134, in validate_jit_parameters
#     p = default_jit_parameters()
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/site-packages/ffc/parameters.py", line 106, in default_jit_parameters
#     parameters = default_parameters()
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/site-packages/ffc/parameters.py", line 98, in default_parameters
#     r = os.environ.get("FFC_FORCE_REPRESENTATION")
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/_collections_abc.py", line 598, in get
#     except KeyError:
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-5388f44dd57a> in <module>()
#     120
#     121         parpool = mp.Pool(trainingData.samples.size)
# --> 122         modelParams.paramsVec = parpool.map(varinf, args)
#     123         parpool.close()
#     124
#
# ~/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/pool.py in map(self, func, iterable, chunksize)
#     264         in a list that is returned.
#     265         '''
# --> 266         return self._map_async(func, iterable, mapstar, chunksize).get()
#     267
#     268     def starmap(self, func, iterable, chunksize=None):
#
# ~/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/pool.py in get(self, timeout)
#     636
#     637     def get(self, timeout=None):
# --> 638         self.wait(timeout)
#     639         if not self.ready():
#     640             raise TimeoutError
#
# ~/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/pool.py in wait(self, timeout)
#     633
#     634     def wait(self, timeout=None):
# --> 635         self._event.wait(timeout)
#     636
#     637     def get(self, timeout=None):
#
# ~/.conda/envs/pyadjoint/lib/python3.5/threading.py in wait(self, timeout)
#     547             signaled = self._flag
#     548             if not signaled:
# --> 549                 signaled = self._cond.wait(timeout)
#     550             return signaled
#     551
#
# ~/.conda/envs/pyadjoint/lib/python3.5/threading.py in wait(self, timeout)
#     291         try:    # restore state no matter what (e.g., KeyboardInterrupt)
#     292             if timeout is None:
# --> 293                 waiter.acquire()
#     294                 gotit = True
#     295             else:
#
# KeyboardInterrupt:
# Process ForkPoolWorker-43:
# Process ForkPoolWorker-47:
# Process ForkPoolWorker-44:
# Process ForkPoolWorker-46:
# Process ForkPoolWorker-42:
# Process ForkPoolWorker-45:
# Process ForkPoolWorker-49:
# Process ForkPoolWorker-48:
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
# Traceback (most recent call last):
# Traceback (most recent call last):
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/process.py", line 252, in _bootstrap
#     self.run()
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/process.py", line 93, in run
#     self._target(*self._args, **self._kwargs)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/queues.py", line 335, in get
#     res = self._reader.recv_bytes()
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/pool.py", line 108, in worker
#     task = get()
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/connection.py", line 216, in recv_bytes
#     buf = self._recv_bytes(maxlength)
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/queues.py", line 334, in get
#     with self._rlock:
# KeyboardInterrupt
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/connection.py", line 407, in _recv_bytes
#     buf = self._recv(4)
# KeyboardInterrupt
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
# KeyboardInterrupt
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/synchronize.py", line 96, in __enter__
#     return self._semlock.__enter__()
#   File "/home/constantin/.conda/envs/pyadjoint/lib/python3.5/multiprocessing/connection.py", line 379, in _recv
#     chunk = read(handle, remaining)
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
# KeyboardInterrupt
